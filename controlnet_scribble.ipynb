# %%
# !pip install diffusers

# %%
# !pip3 install torch torchvision torchaudio

# %%
from diffusers import StableDiffusionControlNetPipeline
from diffusers.utils.testing_utils import load_image
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !pip install opencv-contrib-python

# %%
# !pip install diffusers transformers git+https://github.com/huggingface/accelerate.git
# Out:
# ...
#   Cloning https://github.com/huggingface/accelerate.git to c:\users\kiit\appdata\local\temp\pip-req-build-jtkttz63
#   Resolved https://github.com/huggingface/accelerate.git to commit 565152183334f709ac955204ef663023d1f63b7a
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Running command git clone -q https://github.com/huggingface/accelerate.git 'C:\Users\KIIT\AppData\Local\Temp\pip-req-build-jtkttz63'
# ...

# %%
# !pip install controlnet_aux --user
# Out:
# ...
#   Using cached controlnet_aux-0.0.3-py3-none-any.whl (122 kB)
# ...
#   Using cached timm-0.6.13-py3-none-any.whl (549 kB)
# ...
#   Using cached einops-0.6.1-py3-none-any.whl (42 kB)
# ...

# %%
from controlnet_aux import HEDdetector

# %%
hed = HEDdetector.from_pretrained('lllyasviel/ControlNet')

# %%
image = load_image(
    "C:/Users/KIIT/OneDrive/Desktop/DS/images.png"
)

# %% [markdown]
# ![images.png](attachment:images.png)

# %%
image = hed(image, scribble=True)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x768 at 0x174020AEAC0>

# %%
controlnet = ControlNetModel.from_pretrained(
    "lllyasviel/sd-controlnet-scribble", torch_dtype=torch.float32
)

# %%
pipe = StableDiffusionControlNetPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5", controlnet=controlnet, safety_checker=None, torch_dtype=torch.float32
)
# Out:
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion_controlnet.StableDiffusionControlNetPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
image = pipe("selena gomez in saree", image, num_inference_steps=20).images[0]
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x768 at 0x17553E26C70>
